# %% [markdown]
# # Vivino Scraping  Analysis

# %%
# importo le librerie necessarie 
import numpy as np
import pandas as pd

# %matplotlib inline 
import matplotlib   
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vivino = pd.read_csv('Scraping_Vivino_csv/Scraper.csv') 
vivino.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                           name  \
# 0             0           0                             Sesto 21 Sauvignon
# 1             1           1                      Nussbaumer Gewürztraminer
# 2             2           2  Albertus Viljoen Limited Release Chenin Blanc
# 3             3           3                                      Orestilla
# 4             4           4                       Sanct Valentin Sauvignon
#
#              grape  product rating number ratings product type  \
# 0  Sauvignon Blanc             4.5     62 ratings   White wine
# 1   Gewürztraminer             4.4     64 ratings   White wine
# 2     Chenin Blanc             4.4     45 ratings   White wine
# 3         Turbiana             4.4     26 ratings   White wine
# 4  Sauvignon Blanc             4.3    584 ratings   White wine
#
#   country of origin   price bold_value tannic value sweet_value acidic_value  \
# 0             Italy  €18.50   42.9805%     24.1716%    68.1926%          NaN
# 1             Italy  €27.70    66.025%     41.1219%    27.2879%          NaN
# 2      South Africa  €27.65   42.4188%     13.5308%    69.2572%          NaN
# 3             Italy  €26.30   63.0832%      22.848%     50.515%          NaN
# 4             Italy  €24.40   62.3226%     22.0402%    53.2072%          NaN
#
#   food_pairing
# 0   Vegetarian
# 1         Pork
# 2    Shellfish
# 3    Shellfish
# 4    Shellfish

# %%
vivino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4451 entries, 0 to 4450
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       4451 non-null   int64
#  1   Unnamed: 0         4451 non-null   int64
#  2   name               4451 non-null   object
#  3   grape              4418 non-null   object
#  4   product rating     4451 non-null   float64
#  5   number ratings     4451 non-null   object
#  6   product type       4451 non-null   object
#  7   country of origin  4451 non-null   object
#  8   price              4451 non-null   object
#  9   bold_value         3470 non-null   object
#  10  tannic value       3417 non-null   object
#  11  sweet_value        3289 non-null   object
#  12  acidic_value       1681 non-null   object
#  13  food_pairing       4451 non-null   object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 487.0+ KB

# %% [markdown]
# ## Pulizia DF Vivino

# %%
# elimino due colonne 
vivino = vivino.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)

# %%
# Modifica dei Dtype del DF Vivino

# %%
vivino['number ratings'] = vivino['number ratings'].replace("ratings","",regex=True).astype('int32')

# %%
vivino['price'] = vivino['price'].replace("€","",regex=True).astype('float')

# %%
# per aggiungere il simbolo € si può usare una lambda function, però questa funzione riporta il Dtype in object
''' vivino['price'] = vivino['price'].apply(lambda x: '€{:.2f}'.format(x)) '''
# Out:
# " vivino['price'] = vivino['price'].apply(lambda x: '€{:.2f}'.format(x)) "

# %%
vivino['bold_value'] = vivino['bold_value'].replace("%","",regex=True).astype('float')

# %%
vivino['tannic value'] = vivino['tannic value'].replace("%","",regex=True).astype('float')

# %%
vivino['sweet_value'] = vivino['sweet_value'].replace("%","",regex=True).astype('float')

# %%
vivino['acidic_value'] = vivino['acidic_value'].replace("%","",regex=True).astype('float')

# %%
vivino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4451 entries, 0 to 4450
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               4451 non-null   object
#  1   grape              4418 non-null   object
#  2   product rating     4451 non-null   float64
#  3   number ratings     4451 non-null   int32
#  4   product type       4451 non-null   object
#  5   country of origin  4451 non-null   object
#  6   price              4451 non-null   float64
#  7   bold_value         3470 non-null   float64
#  8   tannic value       3417 non-null   float64
#  9   sweet_value        3289 non-null   float64
#  10  acidic_value       1681 non-null   float64
#  11  food_pairing       4451 non-null   object
# dtypes: float64(6), int32(1), object(5)
# memory usage: 400.0+ KB

# %%
vivino.isna().sum()
# Out:
# name                    0
# grape                  33
# product rating          0
# number ratings          0
# product type            0
# country of origin       0
# price                   0
# bold_value            981
# tannic value         1034
# sweet_value          1162
# acidic_value         2770
# food_pairing            0
# dtype: int64

# %%
# Sostituisco solo i Nan della colonna Grape con Unrecognized grape
vivino['grape'].fillna('Unrecognized grape', inplace=True)

# %%
vivino.isna().sum()
# Out:
# name                    0
# grape                   0
# product rating          0
# number ratings          0
# product type            0
# country of origin       0
# price                   0
# bold_value            981
# tannic value         1034
# sweet_value          1162
# acidic_value         2770
# food_pairing            0
# dtype: int64

# %%
vivino.head(3)
# Out:
#                                             name            grape  \
# 0                             Sesto 21 Sauvignon  Sauvignon Blanc
# 1                      Nussbaumer Gewürztraminer   Gewürztraminer
# 2  Albertus Viljoen Limited Release Chenin Blanc     Chenin Blanc
#
#    product rating  number ratings product type country of origin  price  \
# 0             4.5              62   White wine             Italy  18.50
# 1             4.4              64   White wine             Italy  27.70
# 2             4.4              45   White wine      South Africa  27.65
#
#    bold_value  tannic value  sweet_value  acidic_value food_pairing
# 0     42.9805       24.1716      68.1926           NaN   Vegetarian
# 1     66.0250       41.1219      27.2879           NaN         Pork
# 2     42.4188       13.5308      69.2572           NaN    Shellfish

# %%
# Riordino le colonne 
vivino = vivino[['product type', 'country of origin','name', 'grape', 'product rating', 'number ratings','price','bold_value','tannic value','sweet_value','acidic_value','food_pairing']]

# %%
# Rinomino le colonne 
vivino.columns = ['Product type', 'Country of origin','Name', 'Grape', 'Product rating', 'Number ratings','Price €','Bold value %','Tannic value %','Sweet value %','Acidic value %','Food pairing']

# %%
vivino.head()
# Out:
#   Product type Country of origin  \
# 0   White wine             Italy
# 1   White wine             Italy
# 2   White wine      South Africa
# 3   White wine             Italy
# 4   White wine             Italy
#
#                                             Name            Grape  \
# 0                             Sesto 21 Sauvignon  Sauvignon Blanc
# 1                      Nussbaumer Gewürztraminer   Gewürztraminer
# 2  Albertus Viljoen Limited Release Chenin Blanc     Chenin Blanc
# 3                                      Orestilla         Turbiana
# 4                       Sanct Valentin Sauvignon  Sauvignon Blanc
#
#    Product rating  Number ratings  Price €  Bold value %  Tannic value %  \
# 0             4.5              62    18.50       42.9805         24.1716
# 1             4.4              64    27.70       66.0250         41.1219
# 2             4.4              45    27.65       42.4188         13.5308
# 3             4.4              26    26.30       63.0832         22.8480
# 4             4.3             584    24.40       62.3226         22.0402
#
#    Sweet value %  Acidic value % Food pairing
# 0        68.1926             NaN   Vegetarian
# 1        27.2879             NaN         Pork
# 2        69.2572             NaN    Shellfish
# 3        50.5150             NaN    Shellfish
# 4        53.2072             NaN    Shellfish

# %% [markdown]
# ## Analisi DF Vivino

# %%
vivino.head()
# Out:
#   Product type Country of origin  \
# 0   White wine             Italy
# 1   White wine             Italy
# 2   White wine      South Africa
# 3   White wine             Italy
# 4   White wine             Italy
#
#                                             Name            Grape  \
# 0                             Sesto 21 Sauvignon  Sauvignon Blanc
# 1                      Nussbaumer Gewürztraminer   Gewürztraminer
# 2  Albertus Viljoen Limited Release Chenin Blanc     Chenin Blanc
# 3                                      Orestilla         Turbiana
# 4                       Sanct Valentin Sauvignon  Sauvignon Blanc
#
#    Product rating  Number ratings  Price €  Bold value %  Tannic value %  \
# 0             4.5              62    18.50       42.9805         24.1716
# 1             4.4              64    27.70       66.0250         41.1219
# 2             4.4              45    27.65       42.4188         13.5308
# 3             4.4              26    26.30       63.0832         22.8480
# 4             4.3             584    24.40       62.3226         22.0402
#
#    Sweet value %  Acidic value % Food pairing
# 0        68.1926             NaN   Vegetarian
# 1        27.2879             NaN         Pork
# 2        69.2572             NaN    Shellfish
# 3        50.5150             NaN    Shellfish
# 4        53.2072             NaN    Shellfish

# %% [markdown]
# #### Analisi sul Rating

# %%
# Tipologia di vini più recensiti
grape_ratings = vivino.groupby('Product type')['Product rating'].agg(['sum', 'mean','min','max'])
grape_ratings.reset_index(drop=False)
# Out:
#      Product type     sum      mean  min  max
# 0        Red wine  8489.8  4.249149  4.1  4.7
# 1       Rosé wine  1255.1  3.946855  3.8  4.3
# 2  Sparkling wine  2517.5  3.964567  3.7  4.7
# 3      White wine  6252.1  4.168067  4.1  4.5

# %%
# Analisi di valutazione in stelline da 0.0 a 5.0 per Paese
country_star_ratings = vivino.groupby('Country of origin')['Product rating'].agg(['count', 'mean','min','max'])
country_star_ratings.reset_index(drop=False)
# Out:
#    Country of origin  count      mean  min  max
# 0          Argentina     24  4.129167  3.8  4.2
# 1            Armenia      7  4.200000  4.2  4.2
# 2          Australia      2  3.900000  3.9  3.9
# 3            Austria     14  4.142857  4.1  4.2
# 4              Chile      7  4.200000  4.2  4.2
# 5            Croatia      5  4.100000  4.1  4.1
# 6             Cyprus      2  4.200000  4.2  4.2
# 7             France    205  4.085366  3.8  4.4
# 8            Germany     28  4.125000  3.9  4.2
# 9             Greece     16  4.075000  3.8  4.2
# 10           Hungary     37  4.183784  3.9  4.3
# 11            Israel      5  4.100000  4.1  4.1
# 12             Italy   3881  4.164339  3.7  4.7
# 13       New Zealand     45  4.140000  4.1  4.2
# 14            Poland      4  4.100000  4.1  4.1
# 15          Portugal     28  4.196429  4.1  4.2
# 16          Slovenia      8  4.275000  4.1  4.3
# 17      South Africa     67  4.167164  3.8  4.4
# 18             Spain     54  4.131481  3.8  4.3
# 19     United States      5  4.100000  4.1  4.1
# 20           Uruguay      7  4.200000  4.2  4.2

# %%
#Paese con la Recensione più alta
best_country = country_star_ratings['max'].idxmax()
print("Paese con il conteggio delle Product rating maggiore è:", best_country)
# Out:
# Paese con il conteggio delle Product rating maggiore è: Italy

# %%
# Vino e Punteggio più alto
result_red = vivino.loc[(vivino['Product type'] == 'Red wine') & (vivino['Product rating'] >= 4.5), ['Product type', 'Name','Product rating']]
result_red.sort_values(by='Product rating', ascending=False)
# Out:
#      Product type                                            Name  \
# 2453     Red wine                               Fico Susumaniello
# 2953     Red wine                               Fico Susumaniello
# 3551     Red wine                               Fico Susumaniello
# 3252     Red wine                               Fico Susumaniello
# 2678     Red wine                               Fico Susumaniello
# 4226     Red wine                               Fico Susumaniello
# 3876     Red wine                               Fico Susumaniello
# 3552     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 3553     Red wine                    Limited Edition 10 Vendemmie
# 3554     Red wine                                  Fanova Riserva
# 3555     Red wine             Amarone della Valpolicella Classico
# 3556     Red wine               Lucretia Chianti Classico Riserva
# 3557     Red wine                 Luminaria Primitivo di Manduria
# 3877     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 3878     Red wine                    Limited Edition 10 Vendemmie
# 3257     Red wine               Lucretia Chianti Classico Riserva
# 3879     Red wine                                  Fanova Riserva
# 3880     Red wine             Amarone della Valpolicella Classico
# 3881     Red wine               Lucretia Chianti Classico Riserva
# 3882     Red wine                 Luminaria Primitivo di Manduria
# 4227     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 4228     Red wine                    Limited Edition 10 Vendemmie
# 4229     Red wine                                  Fanova Riserva
# 4230     Red wine             Amarone della Valpolicella Classico
# 4231     Red wine               Lucretia Chianti Classico Riserva
# 3258     Red wine                 Luminaria Primitivo di Manduria
# 3255     Red wine                                  Fanova Riserva
# 3256     Red wine             Amarone della Valpolicella Classico
# 2454     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 2455     Red wine                    Limited Edition 10 Vendemmie
# 2456     Red wine                                  Fanova Riserva
# 2457     Red wine             Amarone della Valpolicella Classico
# 2458     Red wine               Lucretia Chianti Classico Riserva
# 2459     Red wine                 Luminaria Primitivo di Manduria
# 2679     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 2680     Red wine                    Limited Edition 10 Vendemmie
# 2681     Red wine                                  Fanova Riserva
# 2682     Red wine             Amarone della Valpolicella Classico
# 2683     Red wine               Lucretia Chianti Classico Riserva
# 2684     Red wine                 Luminaria Primitivo di Manduria
# 2954     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 2955     Red wine                    Limited Edition 10 Vendemmie
# 2956     Red wine                                  Fanova Riserva
# 2957     Red wine             Amarone della Valpolicella Classico
# 2958     Red wine               Lucretia Chianti Classico Riserva
# 2959     Red wine                 Luminaria Primitivo di Manduria
# 3253     Red wine  60 Sessantanni Old Vines Primitivo di Manduria
# 3254     Red wine                    Limited Edition 10 Vendemmie
# 4232     Red wine                 Luminaria Primitivo di Manduria
#
#       Product rating
# 2453             4.7
# 2953             4.7
# 3551             4.7
# 3252             4.7
# 2678             4.7
# 4226             4.7
# 3876             4.7
# 3552             4.5
# 3553             4.5
# 3554             4.5
# 3555             4.5
# 3556             4.5
# 3557             4.5
# 3877             4.5
# 3878             4.5
# 3257             4.5
# 3879             4.5
# 3880             4.5
# 3881             4.5
# 3882             4.5
# 4227             4.5
# 4228             4.5
# 4229             4.5
# 4230             4.5
# 4231             4.5
# 3258             4.5
# 3255             4.5
# 3256             4.5
# 2454             4.5
# 2455             4.5
# 2456             4.5
# 2457             4.5
# 2458             4.5
# 2459             4.5
# 2679             4.5
# 2680             4.5
# 2681             4.5
# 2682             4.5
# 2683             4.5
# 2684             4.5
# 2954             4.5
# 2955             4.5
# 2956             4.5
# 2957             4.5
# 2958             4.5
# 2959             4.5
# 3253             4.5
# 3254             4.5
# 4232             4.5

# %%
# Tipi di Vino e Punteggio più alto
result_white = vivino.loc[(vivino['Product type'] == 'White wine') & (vivino['Product rating'] >= 4.5), ['Product type', 'Name','Product rating']]
result_white.sort_values(by='Product rating', ascending=False)
# Out:
#      Product type                Name  Product rating
# 0      White wine  Sesto 21 Sauvignon             4.5
# 225    White wine  Sesto 21 Sauvignon             4.5
# 475    White wine  Sesto 21 Sauvignon             4.5
# 750    White wine  Sesto 21 Sauvignon             4.5
# 1050   White wine  Sesto 21 Sauvignon             4.5
# 1375   White wine  Sesto 21 Sauvignon             4.5

# %%
# Vino e Punteggio più alto
result_rose = vivino.loc[(vivino['Product type'] == 'Rosé wine') & (vivino['Product rating'] >= 4.5), ['Product type', 'Name','Product rating']]
result_rose.sort_values(by='Product rating', ascending=False)
# Out:
# Empty DataFrame
# Columns: [Product type, Name, Product rating]
# Index: []

# %%
# Vino e Punteggio più alto
result_sparkling = vivino.loc[(vivino['Product type'] == 'Sparkling wine') & (vivino['Product rating'] >= 4.5), ['Product type', 'Name','Product rating']]
result_sparkling.sort_values(by='Product rating', ascending=False)
# Out:
#         Product type                   Name  Product rating
# 1500  Sparkling wine  Ladies Spumante Dolce             4.7
# 1999  Sparkling wine  Ladies Spumante Dolce             4.7

# %%
# Solo i 4 tipi di Vino che hanno il Rating piu alto
types_of_wine = ['Red wine', 'White wine', 'Sparkling wine', 'Rosé wine']

# Inizializza un dataframe vuoto
result_df = pd.DataFrame(columns=['Product type', 'Name', 'Product rating'])

# Per ogni tipo di vino, seleziona le righe corrispondenti, ordina per rating e seleziona il primo elemento
for wine_type in types_of_wine:
    filtered_df = vivino[vivino['Product type'] == wine_type]
    sorted_df = filtered_df.sort_values(by='Product rating', ascending=False)
    top_rated_wine = sorted_df.iloc[0][['Product type', 'Name', 'Product rating']]
    result_df = result_df.append(top_rated_wine, ignore_index=True)

# Visualizza i risultati
result_df.head()
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\1071194406.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\1071194406.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\1071194406.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\1071194406.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
#      Product type                   Name  Product rating
# 0        Red wine      Fico Susumaniello             4.7
# 1      White wine     Sesto 21 Sauvignon             4.5
# 2  Sparkling wine  Ladies Spumante Dolce             4.7
# 3       Rosé wine     Furía di Calafuria             4.3

# %% [markdown]
# #### Analisi sul Prezzo

# %%
#Groupby su Price per osservare quali sono i Tipi di vino più o meno costosi
vivino.groupby("Product type")["Price €"].agg(['count','sum','mean','min','max']).reset_index(drop=False)
# Out:
#      Product type  count       sum       mean  min   max
# 0        Red wine   1998  43401.08  21.722262  7.0  30.0
# 1       Rosé wine    318   4575.00  14.386792  7.0  62.0
# 2  Sparkling wine    635  12318.51  19.399228  7.4  70.0
# 3      White wine   1500  31424.61  20.949740  7.8  30.0

# %%
# Solo i 4 tipi di Vino che hanno il Price piu alto
types_of_wine = ['Red wine', 'White wine', 'Sparkling wine', 'Rosé wine']

# Inizializza un dataframe vuoto
result_df = pd.DataFrame(columns=['Product type', 'Name', 'Price €'])

# Per ogni tipo di vino, seleziona le righe corrispondenti, ordina per rating e seleziona il primo elemento
for wine_type in types_of_wine:
    filtered_df = vivino[vivino['Product type'] == wine_type]
    sorted_df = filtered_df.sort_values(by='Price €', ascending=False)
    top_rated_wine = sorted_df.iloc[0][['Product type', 'Name', 'Price €']]
    result_df = result_df.append(top_rated_wine, ignore_index=True)

# Visualizza i risultati
result_df.head()
# Out:
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\2304813591.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\2304813591.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\2304813591.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
# C:\Users\leona\AppData\Local\Temp\ipykernel_20364\2304813591.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(top_rated_wine, ignore_index=True)
#      Product type                                 Name  Price €
# 0        Red wine  Amarone della Valpolicella Classico     30.0
# 1      White wine                      Prail Sauvignon     30.0
# 2  Sparkling wine                 Perlé Bianco Riserva     70.0
# 3       Rosé wine                    Alìe Rosé Toscana     62.0

# %%
#Il vino più caro con relative Vendite(N. ratings)
best_wine_price= vivino.groupby(['Product type','Name', 'Country of origin','Number ratings','Product rating'])['Price €'].sum().astype(int).reset_index(drop=False)
best_wine_price.sort_values(by='Price €', ascending=False).head(1)
# Out:
#     Product type                            Name Country of origin  \
# 223     Red wine  Marùn Barbera d'Alba Superiore             Italy
#
#      Number ratings  Product rating  Price €
# 223             107             4.2      281

# %%
#Il vino meno caro con relative Vendite(N. ratings)
best_wine_price= vivino.groupby(['Product type','Name', 'Country of origin','Number ratings','Product rating'])['Price €'].sum().astype(int).reset_index(drop=False)
best_wine_price.sort_values(by='Price €', ascending=True).head(1)
# Out:
#        Product type                               Name Country of origin  \
# 854  Sparkling wine  Lambrusco dell'Emilia Dolce Rosso             Italy
#
#      Number ratings  Product rating  Price €
# 854            4545             3.8        7

# %% [markdown]
# #### Analisi sulle Vendite

# %%
# Tipologia di vini più venduti
grape_ratings = vivino.groupby('Product type')['Number ratings'].agg(['sum', 'mean','min','max'])
grape_ratings.reset_index(drop=False)
# Out:
#      Product type      sum        mean  min    max
# 0        Red wine  1919870  960.895896   25  63691
# 1       Rosé wine    75924  238.754717   25   5682
# 2  Sparkling wine   482260  759.464567   25  24852
# 3      White wine   430764  287.176000   25   4252

# %%
# Analisi del paese con piu vendite
country_numb_ratings = vivino.groupby('Country of origin')['Number ratings'].sum()
country_numb_ratings.reset_index(drop=False)
# Out:
#    Country of origin  Number ratings
# 0          Argentina           24829
# 1            Armenia            4004
# 2          Australia              52
# 3            Austria            2693
# 4              Chile            1757
# 5            Croatia            1215
# 6             Cyprus              80
# 7             France          106810
# 8            Germany            5150
# 9             Greece            7628
# 10           Hungary            4783
# 11            Israel            1020
# 12             Italy         2276587
# 13       New Zealand           33434
# 14            Poland             568
# 15          Portugal           19677
# 16          Slovenia             572
# 17      South Africa           38748
# 18             Spain          372301
# 19     United States            3865
# 20           Uruguay            3045

# %%
# Miglior Paese per Vendita
max_value = max(country_numb_ratings)
max_value = country_numb_ratings.nlargest(1)
max_value.reset_index(drop=False)
# Out:
#   Country of origin  Number ratings
# 0             Italy         2276587

# %%
#Vini piu acquistati e recensiti
best_name_ratings = vivino.groupby(['Country of origin','Product type','Name','Grape'])['Number ratings'].sum()
best_name_ratings.reset_index(drop=False).sort_values(by='Number ratings',ascending=False).head()
# Out:
#      Country of origin Product type  \
# 190              Italy     Red wine
# 1097             Spain     Red wine
# 180              Italy     Red wine
# 116              Italy     Red wine
# 328              Italy     Red wine
#
#                                                 Name       Grape  \
# 190                        Edizione Cinque Autoctoni  Sangiovese
# 1097                                 Mucho Más Tinto       Blend
# 180                             Cinquanta Collezione  Negroamaro
# 116   60 Sessantanni Old Vines Primitivo di Manduria   Primitivo
# 328           Ripassa Valpolicella Ripasso Superiore       Blend
#
#       Number ratings
# 190           445823
# 1097          338214
# 180           254576
# 116           118067
# 328            70406

# %%
#Vini meno acquistati e recensiti
min_name_ratings = vivino.groupby(['Country of origin','Name','Grape'])['Number ratings'].sum()
min_name_ratings.reset_index(drop=False).sort_values(by='Number ratings').head()
# Out:
#      Country of origin                                        Name  \
# 341              Italy                            Cuveé Extra Brut
# 645              Italy  Maior Valdobbiadene Prosecco Superiore Dry
# 52              France                     Envol Crémant de Savoie
# 292              Italy             Cavalè Barbera d'Asti Superiore
# 1097             Spain          Cava Mil.Lenni Reserva Brut Nature
#
#                  Grape  Number ratings
# 341              Blend              25
# 645   Glera (Prosecco)              25
# 52               Blend              25
# 292            Barbera              25
# 1097             Blend              26

# %%
#I vini più Venduti con le valutazione (stelline) più alte
best_wine_region= vivino.groupby(['Product type','Name', 'Country of origin','Number ratings'])['Product rating'].mean().astype(int).reset_index(drop=False)
best_wine_region.sort_values(by='Number ratings', ascending=False).head()
# Out:
#     Product type                       Name Country of origin  Number ratings  \
# 129     Red wine  Edizione Cinque Autoctoni             Italy           63691
# 128     Red wine  Edizione Cinque Autoctoni             Italy           63690
# 127     Red wine  Edizione Cinque Autoctoni             Italy           63689
# 126     Red wine  Edizione Cinque Autoctoni             Italy           63688
# 125     Red wine  Edizione Cinque Autoctoni             Italy           63687
#
#      Product rating
# 129               4
# 128               4
# 127               4
# 126               4
# 125               4

# %%
# Paese con il tipo di Uva(grape) più comprata/recensita
best_grape_ratings = vivino.groupby(['Country of origin','Grape'])['Number ratings'].sum()
best_grape_ratings.reset_index(drop=False).sort_values(by='Number ratings',ascending=False).head(10)
# Out:
#     Country of origin             Grape  Number ratings
# 118             Italy        Sangiovese          478258
# 49              Italy             Blend          385033
# 158             Spain             Blend          344931
# 110             Italy         Primitivo          284842
# 95              Italy        Negroamaro          278333
# 58              Italy        Chardonnay          134396
# 86              Italy     Montepulciano           98129
# 74              Italy             Glera           75982
# 75              Italy  Glera (Prosecco)           45503
# 10             France             Blend           43616

# %%
# Paese con il tipo di Uva(grape) meno comprata/recensita
min_grape_ratings = vivino.groupby(['Country of origin','Grape'])['Number ratings'].sum()
min_grape_ratings.reset_index(drop=False).sort_values(by='Number ratings').head(10)
# Out:
#     Country of origin              Grape  Number ratings
# 59              Italy       Chenin Blanc              27
# 64              Italy            Durella              43
# 3           Australia              Blend              52
# 150          Slovenia         Pinot Noir              54
# 44              Italy  Alicante Bouschet              56
# 60              Italy         Ciliegiolo              62
# 54              Italy           Carignan              64
# 160             Spain           Malvasia              65
# 126             Italy     Tocai Friulano              68
# 70              Italy          Gaglioppo              70

# %% [markdown]
# #### Analisi sulla Valutazione Rating/Price (Convenienza)

# %%
# Nuova colonna che calcola il rapporto tra Rating e Price 
vivino["Rating Price Ratio"] = vivino["Product rating"] / vivino["Price €"]

# %%
#Massimi valori della colonna "rating_price_ratio".
vivino.sort_values(by='Rating Price Ratio', ascending=False).head()

# %%
# creo dei bin dove idati con valori compresi tra 0.0 e 0.20 saranno assegnati al primo bin, 
#i dati compresi tra 0.20 e 0.40 saranno assegnati al secondo bin, 
#i dati con valori compresi tra 0.40 e  saranno assegnati al terzo bin.
bins = [0.0, 0.2, 0.4, 1.0]

# %%
# Creo una nuova colonna "Rating category" che mi permette di creare dei valori "Excellent", "Medium" o "Poor" in base al rating
vivino['Rating category'] = pd.cut(vivino['Rating Price Ratio'], bins=bins , labels=['Low', 'Medium', 'Excellent'])
vivino.head(10)   #i quantili megli farli sul Rating o sul rating price Ratio?????

# %%
# Il mioglior Vino Rating - Price
sorted_data = vivino.sort_values(by='Rating Price Ratio', ascending=False)
best_wine_rp = sorted_data.iloc[0]
best_wine_rp

# %%
# Il peggior Vino Rating - Price
sorted_data = vivino.sort_values(by='Rating Price Ratio')
worst_wine_rp = sorted_data.iloc[0]
worst_wine_rp

# %%
# conto il numero di tipi di vino con rating "Excellent"
num_excellent = (vivino['Rating category'] == 'Excellent').sum()
print("Numero di vini con un rating 'Excellent':", num_excellent)

# %%
# conta il numero di tipi di vino con rating "Medium"
num_medium = (vivino['Rating category'] == 'Medium').sum()
print("Numero di vini con un rating 'Medium':", num_medium)

# %%
# conta il numero di tipi di vino con rating "Low"
num_low = (vivino['Rating category'] == 'Low').sum()
print("Numero di vini con un rating 'Low':", num_low)
